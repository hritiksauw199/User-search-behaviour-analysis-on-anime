# %%
import pandas as pd

# %%
df = pd.read_csv('cloud.csv')
df
# Out:
#      uid       profile  anime_uid  \
# 0    335      09io78ty       1571
# 1    274     Stormy_77         82
# 2     59          Wyko        790
# 3   3421   underMebius       1594
# 4    180       Kopanda         66
# ..   ...           ...        ...
# 92  1182        Venneh        529
# 93  1136     Master10K       1860
# 94   571  edythemighty       1576
# 95   616      Traversy        785
# 96   522       JackCox        189
#
#                                                  text  score  \
# 0   \n           \n         \n           \n       ...     10
# 1   \n           \n         \n           \n       ...      9
# 2   \n           \n         \n           \n       ...      9
# 3   \n           \n         \n           \n       ...     10
# 4   \n           \n         \n           \n       ...     10
# ..                                                ...    ...
# 92  \n           \n         \n           \n       ...      9
# 93  \n           \n         \n           \n       ...      8
# 94  \n           \n         \n           \n       ...      9
# 95  \n           \n         \n           \n       ...      7
# 96  \n           \n         \n           \n       ...      5
#
#                                                scores  \
# 0   {'Overall': '10', 'Story': '9', 'Animation': '...
# 1   {'Overall': '9', 'Story': '10', 'Animation': '...
# 2   {'Overall': '9', 'Story': '9', 'Animation': '1...
# 3   {'Overall': '10', 'Story': '9', 'Animation': '...
# 4   {'Overall': '10', 'Story': '8', 'Animation': '...
# ..                                                ...
# 92  {'Overall': '9', 'Story': '9', 'Animation': '8...
# 93  {'Overall': '8', 'Story': '7', 'Animation': '9...
# 94  {'Overall': '9', 'Story': '10', 'Animation': '...
# 95  {'Overall': '7', 'Story': '7', 'Animation': '6...
# 96  {'Overall': '5', 'Story': '5', 'Animation': '4...
#
#                                            link  \
# 0    https://myanimelist.net/reviews.php?id=335
# 1    https://myanimelist.net/reviews.php?id=274
# 2     https://myanimelist.net/reviews.php?id=59
# 3   https://myanimelist.net/reviews.php?id=3421
# 4    https://myanimelist.net/reviews.php?id=180
# ..                                          ...
# 92  https://myanimelist.net/reviews.php?id=1182
# 93  https://myanimelist.net/reviews.php?id=1136
# 94   https://myanimelist.net/reviews.php?id=571
# 95   https://myanimelist.net/reviews.php?id=616
# 96   https://myanimelist.net/reviews.php?id=522
#
#                                          cleaned_text                   title  \
# 0   i love this anime reasons 1 each episode is fu...  matantei loki ragnarok
# 1   this series was only 6 episodes long but packe...             kiddy grade
# 2   in a world where humans and robots live togeth...                 chobits
# 3   the story its actually pretty well not clear a...        kodomo no omocha
# 4   azumanga daioh epitomizes innocent playful and...                vandread
# ..                                                ...                     ...
# 92  title saikano short for saishu heiki kanojo my...       shamanic princess
# 93  this anime has all the classic elements from s...               betterman
# 94  although i havent seen much of this anime i fe...                moldiver
# 95  i thought it might be proper to define quotota...  nurse angel ririka sos
# 96  i know ill probably get flamed for trashing th...              metropolis
#
#      x
# 0    2
# 1    7
# 2    4
# 3   10
# 4    3
# ..  ..
# 92   1
# 93   1
# 94   0
# 95   3
# 96   4
#
# [97 rows x 10 columns]

# %%
columns_to_keep = ['score', 'cleaned_text', 'title']
new_df = df[columns_to_keep]

# %%
new_df
# Out:
#     score                                       cleaned_text  \
# 0      10  i love this anime reasons 1 each episode is fu...
# 1       9  this series was only 6 episodes long but packe...
# 2       9  in a world where humans and robots live togeth...
# 3      10  the story its actually pretty well not clear a...
# 4      10  azumanga daioh epitomizes innocent playful and...
# ..    ...                                                ...
# 92      9  title saikano short for saishu heiki kanojo my...
# 93      8  this anime has all the classic elements from s...
# 94      9  although i havent seen much of this anime i fe...
# 95      7  i thought it might be proper to define quotota...
# 96      5  i know ill probably get flamed for trashing th...
#
#                      title
# 0   matantei loki ragnarok
# 1              kiddy grade
# 2                  chobits
# 3         kodomo no omocha
# 4                 vandread
# ..                     ...
# 92       shamanic princess
# 93               betterman
# 94                moldiver
# 95  nurse angel ririka sos
# 96              metropolis
#
# [97 rows x 3 columns]

# %%
new_df.iloc[87]
# Out:
# score                                                           7
# cleaned_text    earthian is from the late 1980s early 1990s bu...
# title                                                     pokemon
# Name: 87, dtype: object

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Your DataFrame
# df = ...

# Get the cleaned text from row 39
text_to_visualize = new_df.loc[87, 'cleaned_text']

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_to_visualize)

# Display the generated word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
#plt.title('Word Cloud for Row 39')
plt.show()
